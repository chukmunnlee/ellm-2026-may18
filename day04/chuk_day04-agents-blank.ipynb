# %% [markdown]
# # IMPORTANT
#
# Run the following to install smolagents

# %%
# Imports
import os

from smolagents import CodeAgent, OpenAIServerModel
from dotenv import load_dotenv

# %%
# TODO: Import the tools notebook
# %run /content/chuk_day04-tools-blank.ipynb
# Out:
#    id      country            city   latitude  longitude  altitude
# 0   1  Afghanistan           Kabul  34.516667  69.183334      1808
# 1   2  Afghanistan        Kandahar  31.610000  65.699997      1015
# 2   3  Afghanistan  Mazar-e Sharif  36.706944  67.112221       369
# 3   4  Afghanistan           Herat  34.340000  62.189999       927
# 4   5  Afghanistan       Jalalabad  34.420000  70.449997       573

# %%
# TODO: Get the Huggingface token
# IMPORTANT: Before you run this cell, create a file called .env in day04 directory
# and add the following line into the file
# OPENAI_API_KEY=OpenAI_API_key
result = load_dotenv('/content/dot_env')
print(result)
# Out:
# True

# %%
# TODO: Load an agent
model_name = "gpt-4.1-mini"
API_KEY = os.getenv("OPENAI_API_KEY")

# create the 'brain', LLM
agent_model = OpenAIServerModel(model_id=model_name, api_key=API_KEY)

# create the agent
agent = CodeAgent(model=agent_model, tools=[], add_base_tools=True)

# %%
# TODO: List of tools
for t in agent.tools.keys():
  print(t)
# Out:
# web_search
# visit_webpage
# final_answer

# %%
# TODO Run a simple query
agent.run("Create a docker-compose.yaml file to run OpenClaw safely")
# Out:
# ╭──────────────────────────────────────────────────── New run ────────────────────────────────────────────────────╮
# │                                                                                                                 │
# │ Create a docker-compose.yaml file to run OpenClaw safely                                                        │
# │                                                                                                                 │
# ╰─ OpenAIModel - gpt-4.1-mini ────────────────────────────────────────────────────────────────────────────────────╯
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ Step 1 ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
#  ─ Executing parsed code: ────────────────────────────────────────────────────────────────────────────────────────
#   info_openclaw = web_search(query="OpenClaw docker run safe usage")
#   print(info_openclaw)
# ...

# %%
# TODO: Create an agent with our own tools
tools = [ get_latlng, get_temperature, SQLiteTool('/content/data/chinook_sqlite.sqlite') ]

agent = CodeAgent(model=agent_model, tools=tools, add_base_tools=False)

for t in agent.tools.keys():
  print(t)
# Out:
# get_latlng
# get_temperature
# album_track
# final_answer

# %%
# TODO: Perform task with get_latlng and get_temperature function
# TODO: Will switch to duckduckgo if cannot get the temperature from custom functions
agent.run("What is the weather in Clementi. The result should only be obtained from the give tools. If you cannot get the result, return 0 temperature. Return the answer in JSON with the following attributes: city_name, temperatur, unit", max_steps=5)
# Out:
# ╭──────────────────────────────────────────────────── New run ────────────────────────────────────────────────────╮
# │                                                                                                                 │
# │ What is the weather in Clementi. The result should only be obtained from the give tools. If you cannot get the  │
# │ result, return 0 temperature. Return the answer in JSON with the following attributes: city_name, temperatur,   │
# │ unit                                                                                                            │
# │                                                                                                                 │
# ╰─ OpenAIModel - gpt-4.1-mini ────────────────────────────────────────────────────────────────────────────────────╯
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ Step 1 ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
# ...

# %%
#TODO: Rerun the query
band = "michael jackson"
# band = "men At work"
# band = 'james brown'
agent.run("List of songs with country or city names?", max_steps=10)
# Out:
# ╭──────────────────────────────────────────────────── New run ────────────────────────────────────────────────────╮
# │                                                                                                                 │
# │ List of songs with country or city names?                                                                       │
# │                                                                                                                 │
# ╰─ OpenAIModel - gpt-4.1-mini ────────────────────────────────────────────────────────────────────────────────────╯
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ Step 1 ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
#  ─ Executing parsed code: ────────────────────────────────────────────────────────────────────────────────────────
#   # Define some common city and country names to look for in track titles
# ...

# %%
agent.run("List of songs with country or city names?", max_steps=10)
# Out:
# ╭──────────────────────────────────────────────────── New run ────────────────────────────────────────────────────╮
# │                                                                                                                 │
# │ List of songs with country or city names?                                                                       │
# │                                                                                                                 │
# ╰─ OpenAIModel - gpt-4.1-mini ────────────────────────────────────────────────────────────────────────────────────╯
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ Step 1 ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
#  ─ Executing parsed code: ────────────────────────────────────────────────────────────────────────────────────────
#   # List of some common countries and cities to search in song titles
#   places = [
#       'London', 'Paris', 'New York', 'Tokyo', 'Berlin', 'Chicago', 'Sydney',
# ...
